# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from webdriver_manager.firefox import GeckoDriverManager
from webdriver_manager.microsoft import EdgeChromiumDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.edge.service import Service
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.edge.options import Options
import pandas as pd
from collections import Counter
from time import sleep
from random import choice
import re

# %%
ecosia = 'https://www.ecosia.org/search?q=+'
dog='https://www.dogpile.com/serp?q={+}&sc=s73c1zpA888T10'
ekoru = 'https://www.ekoru.org/?q=wood%20screws%20unspsc&target=all&p=1&param=4064ED3579713C3A51045B3E50CFAD0903A11CEB1460BF85326BC761D3A7B9A5'
virtual_mirage = 'https://www.virtualmirage.org/results.html?q=wood+screw+unspsc&cx=015302379428837224239%3Addwdqeqaukk'
neeva = 'https://neeva.com/search?q=wood+screws+unspsc'
yandex='https://yandex.com/search/?text=wood+screws+unspsc&lr=21411'
aol ='https://search.aol.com/aol/search;_ylt=AwrJ61zx1P5hLAQAXH5oCWVH;_ylc=X1MDMTE5NzgwMzg4MARfcgMyBGZyAwRmcjIDc2ItdG9wLXNlYXJjaARncHJpZANsdGRBNlVZWFJkZUREWlBXTHlaZExBBG5fcnNsdAMwBG5fc3VnZwMwBG9yaWdpbgNzZWFyY2guYW9sLmNvbQRwb3MDMARwcXN0cgMEcHFzdHJsAzAEcXN0cmwDMTgEcXVlcnkDd29vZCUyMHNjcmV3cyUyMHVuc3BzYwR0X3N0bXADMTY0NDA5MDYxNw--?q=wood+screws+unspsc&v_t=na&s_it=sb-home&iscqry=&fr=&fr2=sb-top-search'
lycos = 'https://search20.lycos.com/web/?q=wood+screws+unspsc&keyvol=00a9450b1d72bff67ef3'
mojeek = 'https://www.mojeek.com/search?q=wood+screws+unspsc'
webcrawler = 'https://www.webcrawler.com/serp?q=wood+screws+unspsc&sc=q_Nm2XFwzGmA5xHKJpaC10tMG9dYxvB5-5kWciKOb3FlV34gccDStFg7hnLTwR6pr5UISLnPgVLTUpydTYPR6F2E25utbOubg2WCZEboJCJojk1xvke6vUFZVD4P7_P7f_K0E4dfPLilBnG-0Kw_OhtCmko--hbwbOpwtMjddp4_oFoenumMEr9zP24oYelLbTbpkgizF0cGaB63cjUkQm6NRETq4pspAHxVBiVEsuRRTWkMbBob1VU0MsyiM26cZX1Ek_eMKyfnZ0o1pz3vc5tveKMQbkrJ1tHxOozIcivyytF6bMCV0VA7GyHbJ4-KT97JjsnYCGr0CckAuA7Ta_IPCsioQ8bAIieqin1VeGQWhaNSlulacLtBMQOwTXu_iXLQ8dzhVe6Os7xnfc7R31UcpG9QHS5LDIXIwsdJvRJOpRFiAwRGdTkS7OziYMMg9XE6O7DDb5DUzHR0l4gi2abqxHl38roZqghV4DRMf7ZqEsckoIo8uDN68U5rqHh3aNnRZyFIbR3UCKtTf81LbXGjZ_oNA-dsHdcZ8JzfITr5pxfJKHkBKeqD8GIM99fB_RK3WEStkzzBJHPL1ezDTskagDnAnfzKw1oJosmiaSrPYtjoKFRFpoUDBUOK56fGFTVrphQRoW6KhAB_K7ohYwBfHnzRmpccElUHu7a5ar-I5cWI_HTlLezmtHoljYKeftRwKfkV94--hfNIyUDqkYi7C4DAXiYJm1YZmaOUsrl91bHtaGwymghHrQcmZqpxLTsk9l67vHZ8mqcHTpt4mdPizfK7irT00arekqeZwaauwJoUuLHFpUVY_JcDkd4GHmDWlvsHe6S6MSl_OlPdGtLdAcGbEOmbdqjxCxuqAKLsYyCU-Ol7hdQv89KzcKD84JeXsTicyq8B7zj-B_mBkRtl6VcgHlJCDxa1skjIZSO3_29RuWF5jym50IzxpI70ZMSnpPhlGCXewJT2PMA19PEwlSxB8ljQ59NEts_qt6hdvJ5JaMeduWqM9idkMinzi5riiJDXoZ2hRbDT1dYUFn5Qesagyp8Y25fjUEskl_PFwLN-T6s21wODLdUyGabR0gMfrKnAJMAcpIzyJgUi-CGoASGSL4GIq4Fk_mtesMzPLFvgTWO5F77wYdKt395eeVKmGK1ZvrWLqPA_3SeYRczVMu7jU-Q3zlmxK3_Z3bnvBXOb86cOirO6tal1yJNgiS_ceqIcxPw8LTATfcY0LaNpiS4nurw8HlhQZb9RwIh9R4UEZxBdbL114MXVSOoUz1w6GwZLYpAgR9LcN5qGpDBunSUUWaHmKYPY8-2ve1eKr9GmhzGev-K_5TT52J1ZkmrwAueriNH_6K6Y0KF_lYeeuB5JH7I38ILYSdR-pMSdsBlUgLdqRHU-gBGbC8nOOL9rHtGIlLBPerxtWl4bKOEKBl0tMpRs30pRbZRIruaRqbvdKD44To0gL1L7YBFsKI4V7CnhIuvC4HtMesnIitufS8gjOAZ9dIlYiTktiWyPUDw_r_qgw0Ccm-smaX_OzbWkVRCIYrn8Kqxsh7AC2Pu1Bh15xYdgabKTMKfH1ea2HHJJ5jPrWyMqYqzAIKiBIztLiMuUhYh6e8FA9uiUCrJNKt1X5oWpQj3dm2TSdSMJJceDwAfiLy-LsC18hZ_xbPqm5N5_A9-6qWItYgiTIO-NroyvblZ5ho9HXk5YaleE-WZ7IeAzQlHRxma3JlHulh35B-xktElILLsJsKysI-ARS0QAibjhBHRLF-85URIqzR7ub3Vv2744uSROK8aIvA'
metager = 'https://metager3.de/en/meta/meta.ger3?eingabe=wood+screws+unspsc&focus=web'
qmamu = 'https://qmamu.com/search?q=wood%20screws%20unspsc&from=web'
you = 'https://you.com/search?q=wood+screws+unspsc&fromSearchBar=true&tbm=web'
oscobo ='https://www.oscobo.com/search.php?q=wood+screws+unspsc'
lukol = 'https://www.lukol.com/s.php?q=wood+screws+unspsc#gsc.tab=0&gsc.q=wood%20screws%20unspsc&gsc.page=1'
ask = 'https://www.ask.com/web?q=wood%20screws%20unspsc&ad=dirN&o=0'
brave='https://search.brave.com/search?q=wood+screws+unspsc&source=web'

# %%
df = pd.read_csv('New Copy of KelvinUNSPSCProject.xlsx - All In one.csv')

# %%
non_null_com = df[~df['Commodity/Level 4'].isnull()]
list_of_names = non_null_com['Commodity/Level 4'].to_list()

# %%
len(list_of_names)
# Out:
# 6531

# %%
test = list_of_names[:500]
test[0]
# Out:
# 'Adhesive, Graffiti & Rust Removers'

# %%
# unspsc_column_v2 = []
# search_engine_choice = ['duck', 'bing', 'yahoo','qwant','brave','']
# s=Service(ChromeDriverManager().install(),)
# driver =webdriver.Chrome(service=s)
# for query in list_of_names_v2:
#     choice_ = choice(search_engine_choice)
#     if choice_ == 'duck':
#         print('duck')
#         possible = []
#         search_string = query.replace('&', '').replace(' ', '%20')
#         search_string = search_string+'%20unspsc'
#         driver.get(f'https://duckduckgo.com/?q={search_string}++site%3Ahttps%3A%2F%2Fwww.grainger.com')
#         sleep(1)
#         results = driver.find_element(By.XPATH,'//*[@id="links_wrapper"]/div[1]').text
#         results_numbers = re.findall("(\d{8})", results)
#         counter_numbers = Counter(results_numbers).most_common(2)
#         for i in counter_numbers:
#             unspsc, feq = i
#         possible.append(int(unspsc))
#         unspsc_column.append(possible)
#         print("number: ",possible)
#         sleep(2)
#         driver.back()
#         sleep(1) 
#     elif choice_ == 'bing':
#         print('bing')
#         possible = []
#         search_string = query.replace('&', '').replace(' ', '%20')
#         search_string = search_string+'%20unspsc'
#         driver.get(f'https://www.bing.com/search?q={search_string}%20site%3Ahttps%3A%2F%2Fwww.grainger.com')
#         sleep(1)
#         results = driver.find_element(By.XPATH,'//*[@id="b_content"]').text
#         results_numbers = re.findall("(\d{8})", results)
#         counter_numbers = Counter(results_numbers).most_common(2)
#         for i in counter_numbers:
#             unspsc, feq = i
#         possible.append(int(unspsc))
#         unspsc_column.append(possible)
#         print("number: ",possible)
#         sleep(2)
#         driver.back()
#         sleep(1) 
#     elif choice_ == 'yahoo':
#         print('yahoo')
#         possible = []
#         search_string = query.replace('&', '').replace(' ', '%20')
#         search_string = search_string+'%20unspsc'
#         driver.get(f'https://search.yahoo.com/search?p={search_string}+site%3Ahttps%3A%2F%2Fwww.grainger.com')
#         sleep(1)
#         results = driver.find_element(By.XPATH,'//*[@id="results"]').text
#         results_numbers = re.findall("(\d{8})", results)
#         counter_numbers = Counter(results_numbers).most_common(2)
#         for i in counter_numbers:
#             unspsc, feq = i
#         possible.append(int(unspsc))
#         unspsc_column.append(possible)
#         print("number: ",possible)
#         sleep(2)
#         driver.back()
#         sleep(1) 
#     elif choice_ == 'qwant':
#         print('qwant')
#         possible = []
#         search_string = query.replace('&', '').replace(' ', '%20')
#         search_string = search_string+'%20unspsc'
#         driver.get(f'https://www.qwant.com/?q={search_string}+site%3Ahttps%3A%2F%2Fwww.grainger.com')
#         sleep(1)
#         results = driver.find_element(By.XPATH,'//*[@id="root"]/div[2]/div[3]/div[1]').text
#         results_numbers = re.findall("(\d{8})", results)
#         counter_numbers = Counter(results_numbers).most_common(2)
#         for i in counter_numbers:
#             unspsc, feq = i
#         possible.append(int(unspsc))
#         unspsc_column.append(possible)
#         print("number: ",possible)
#         sleep(2)
#         driver.back()
#         sleep(1) 
#     elif choice_ == 'brave':
#         possible = []
#         print('brave')
#         search_string = query.replace('&', '').replace(' ', '+')
#         search_string = search_string+'+unspsc'
#         driver.get(f'https://search.brave.com/search?q={search_string}+site%3Awww.grainger.com&source=web')
#         sleep(1)
#         results = driver.find_element(By.XPATH,'//*[@id="results"]').text
#         results_numbers = re.findall("(\d{8})", results)
#         counter_numbers = Counter(results_numbers).most_common(2)
#         for i in counter_numbers:
#             unspsc, feq = i
#             possible.append(int(unspsc))
#         unspsc_column.append(possible)
#         print("number: ",possible)
#         sleep(2)
#         driver.back()
#         sleep(1)
#     elif choice_ == 'ask':
#         possible = []
#         print('ask')
#         search_string = query.replace('&', '').replace(' ', '+')
#         search_string = search_string+'+unspsc'
#         driver.get(f'https://www.ask.com/web?o=0&l=dir&qo=serpSearchTopBox&q={search_string}+site%3Awww.grainger.com')
#         sleep(1)
#         results = driver.find_element(By.XPATH,'/html/body/div[3]/div/main/div/div[1]/section/div').text
#         results_numbers = re.findall("(\d{8})", results)
#         counter_numbers = Counter(results_numbers).most_common(2)
#         for i in counter_numbers:
#             unspsc, feq = i
#             possible.append(int(unspsc))
#         unspsc_column.append(possible)
#         print("number: ",possible)
#         sleep(2)
#         driver.back()
#         sleep(1)
#     elif choice_ == 'lukol':
#         possible = []
#         print('lukol')
#         search_string = query.replace('&', '').replace(' ', '+')
#         search_string = search_string+'+unspsc'
#         driver.get(f'https://www.lukol.com/s.php?q={search_string}+site%3Awww.grainger.com')
#         sleep(3)
#         results = driver.find_element(By.XPATH,'//*[@id="___gcse_0"]/div').text
#         results_numbers = re.findall("(\d{8})", results)
#         counter_numbers = Counter(results_numbers).most_common(2)
#         for i in counter_numbers:
#             unspsc, feq = i
#             possible.append(int(unspsc))
#         unspsc_column.append(possible)
#         print("number: ",possible)
#         sleep(2)
#         driver.back()
#         sleep(1)
# driver.quit()

# %%
unspsc_column= []
search_engine_choice = ['duck', 'yahoo','ecosia','dog','virtual_mirage',
                        'yandex','aol','lycos','mojeek','webcrawler','metager',
                       'qmamu','you','oscobo','lukol','ask','brave','google']
driver =webdriver.Firefox(executable_path=GeckoDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current firefox version is 96.0
# Get LATEST geckodriver version for 96.0 firefox
# Driver [/Users/kelvinarellano/.wdm/drivers/geckodriver/macos/v0.30.0/geckodriver] found in cache

# %%
print('yandex')
search_string = test[0]
search_string = search_string.replace(',','').replace('&','').replace(' ','+')
search_string = search_string+'+unspsc'
driver.get(f'https://yandex.com/search/?text={search_string}&lr=21411')
sleep(1)
results_1 = driver.find_elements(By.XPATH,'//html/body/div[3]/div[2]/div[2]/div[1]/div[1]/ul/li[17]/div').text
if len(result_1) >= 0:
    print('working')
else:
    print('not working')
# page_2 = driver.find_element(By.XPATH,'/html/body/main/div/div/div/div/div/div/div/div/div[5]/div[2]/div[1]/div/div[2]/div/div[2]').click()
# sleep(1)
# results_2 = driver.find_element(By.XPATH,'/html/body/main/div/div/div/div/div/div/div/div/div[5]/div[2]/div[1]').text
# page_3 = driver.find_element(By.XPATH,'/html/body/main/div/div/div/div/div/div/div/div/div[5]/div[2]/div[1]/div/div[2]/div/div[3]').click()
# sleep(1)
# results_3 = driver.find_element(By.XPATH,'/html/body/main/div/div/div/div/div/div/div/div/div[5]/div[2]/div[1]/div/div[1]').text
# results = results_1+results_2+results_3
# results_numbers = re.findall("(\d{8})", results)
# unspsc_column.append(results_numbers)
# Out:
# yandex
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/lj/1vxn4hgj4xg8y1rp29sbs47w0000gn/T/ipykernel_1123/3486029361.py in <module>
#       5 driver.get(f'https://yandex.com/search/?text={search_string}&lr=21411')
#       6 sleep(1)
# ----> 7 results_1 = driver.find_elements(By.XPATH,'//html/body/div[3]/div[2]/div[2]/div[1]/div[1]/ul/li[17]/div').text
#       8 if len(result_1) >= 0:
#       9     print('working')
#
# AttributeError: 'list' object has no attribute 'text'

# %%
page_2 = driver.find_element(By.XPATH,'/html/body/main/div/div/div/div/div/div/div/div/div[5]/div[2]/div[1]/div/div[2]/div/div[2]').click()
# Out:
# 'Which Rust Remover is Best?! - YouTube\nyoutube.com›watch?v=TE9XiVbWumQ\n11:27\nHD\nWhich Rust Remover is Best?! Смотреть позже. Поделиться. ... Which Rust Remover is Best?! Part 2. Автор: TRG RESTORATION.\nMissing: unspsc, graffiti\nAmazon.com: graffiti remover\namazon.com›graffiti-remover/s?k=graffiti remover\nRating: 4.0 out of 5\n4.0\nStore rating on Yandex.Market\nSafe \'n Easy Graffiti Remover, Spray Paint Remover, Industrial Strength Non-Toxic Gel Removes Paint, Marker, Coating ... Goo Gone Adhesive Remover Spray Gel - 2 Pack and Sticker Lifter - Removes Chewing Gum Grease Tar Stickers Labels Tape Residue Oil...\nMissing: unspsc\nКупить rust-oleum graffiti remover spray / раст-олеум...\nKraski.ru›catalog/rust…graffiti_remover…graffiti…\nRating: 5.0 out of 5\n5.0\nStore rating on Yandex.Market\nЛучшая цена на Rust-Oleum Graffiti Remover Spray / Раст-Олеум Очиститель-смывка граффити и сложных загрязнений в интернет-магазине Краски Ру! Доставка по Москве и МО, бонусы за покупку 
# ...

# %%
# print('vm')
# search_string = test[0]
# search_string = search_string.replace(',','').replace('&','').replace(' ','+')
# search_string = search_string+'+unspsc'
# driver.get(f'https://www.virtualmirage.org/results.html?q={search_string}&cx=015302379428837224239%3Addwdqeqaukk')
# results_1 = driver.find_element(By.XPATH,'/html/body/main/div/div/div/div/div/div/div/div/div[5]/div[2]/div[1]').text
# page_2 = driver.find_element(By.XPATH,'/html/body/main/div/div/div/div/div/div/div/div/div[5]/div[2]/div[1]/div/div[2]/div/div[2]').click()
# sleep(1)
# results_2 = driver.find_element(By.XPATH,'/html/body/main/div/div/div/div/div/div/div/div/div[5]/div[2]/div[1]').text
# page_3 = driver.find_element(By.XPATH,'/html/body/main/div/div/div/div/div/div/div/div/div[5]/div[2]/div[1]/div/div[2]/div/div[3]').click()
# sleep(1)
# results_3 = driver.find_element(By.XPATH,'/html/body/main/div/div/div/div/div/div/div/div/div[5]/div[2]/div[1]/div/div[1]').text
# results = results_1+results_2+results_3
# results_numbers = re.findall("(\d{8})", results)
# unspsc_column.append(results_numbers)
# Out:
# vm

# %%
# print('dog')
# search_string = test[0]
# search_string = search_string.replace(',','').replace('&','').replace(' ',"+")
# search_string = search_string+'+unspsc'
# driver.get(f'https://www.dogpile.com/serp?q={search_string}&sc=KghGjHxK1IFP10')
# results_1 = driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]').text
# page_2 = driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/div[2]/div/a[1]').click()
# sleep(1)
# results_2 = driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]').text
# page_3 = driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/div[2]/div/a[3]').click()
# sleep(1)
# results_3 = driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]').text
# results = results_1+results_2+results_3
# results_numbers = re.findall("(\d{8})", results)
# unspsc_column.append(results_numbers)
# Out:
# dog

# %%
print('ecosia')
search_string = test[0]
search_string = search_string.replace(',','').replace('&','').replace(' ',"+")
search_string = search_string+'+unspsc'
driver.get(f'https://www.ecosia.org/search?q={search_string}')
sleep(1)
page_2 = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div[2]/div/div[1]/div[2]/nav/a[3]').click()
sleep(1)
results_2 = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div[2]/div/div[1]/div[2]').text
page_3 = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div[2]/div/div[1]/div[2]/nav/a[4]').click()
sleep(1)
results_3 = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div[2]/div/div[1]/div[2]').text
results = results_1+results_2+results_3
results_numbers = re.findall("(\d{8})", results)
unspsc_column.append(results_numbers)
# Out:
# ecosia

# %%
# print('yahoo')
# search_string = test[0]
# search_string = search_string.replace(',','').replace('&','').replace(' ',"+")
# search_string = search_string+'+unspsc'
# driver.get(f'https://search.yahoo.com/search;_ylt=AwrJ7Fr6Nv9hI98ArHtDDWVH;_ylc=-?p={search_string}&fr=sfp&fr2=p%3As%2Cv%3Asfp%2Cm%3Asb-top&iscqry=')
# sleep(2)
# results_1 = driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div/div/div[1]/div/div/div/div/ol').text
# page_2 = driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div/div/div[1]/div/ol/li[1]/div/div/div/a[1]').click()
# sleep(2)
# results_2 = driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div/div/div[1]/div/div/div/div/ol').text
# sleep(2)
# page_3 = driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div/div/div[1]/div/ol/li[1]/div/div/div/a[2]').click()
# sleep(2)
# results_3 = driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div/div/div[1]/div/div/div/div/ol').text
# results = results_1+results_2+results_3
# results_numbers = re.findall("(\d{8})", results)
# unspsc_column.append(results_numbers)
# Out:
# yahoo

# %%
# Out:
# []

# %%
# print('duck')
# search_string = test[0]
# search_string = search_string.replace(',','').replace('&','').replace(' ',"+")
# search_string = search_string+'+unspsc'
# driver.get(f'https://duckduckgo.com/?q={search_string}&t=h_&ia=web')
# sleep(2)
# more_1 = driver.find_element(By.XPATH,'/html/body/div[2]/div[5]/div[3]/div/div[1]/div[5]/div[12]/a').click()
# sleep(2)
# more_2 = driver.find_element(By.XPATH,'/html/body/div[2]/div[5]/div[3]/div/div[1]/div[5]/div[34]/a').click()
# sleep(2)
# results_1 = driver.find_element(By.XPATH,'//*[@id="links"]').text
# results_numbers = re.findall("(\d{8})", results_1)
# unspsc_column.append(results_numbers)
# Out:
# duck

# %%
# print('ecosia')
# search_string = test[0]
# search_string = search_string.replace(',','').replace('&','').replace(' ','+')
# search_string = search_string+'+unspsc'
# driver.get(f'https://www.ecosia.org/search?q={search_string}')
# sleep(2)
# results_1 = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div[2]/div/div[1]/div[2]').text
# sleep(2)
# second_page = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div[2]/div/div[1]/div[2]/nav/a[3]').click()
# sleep(2)
# results_2 = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div[2]/div/div[1]/div[2]').text
# sleep(3)
# third_page = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div[2]/div/div[1]/div[2]/nav/a[4]').click()
# sleep(5)
# results_3 = driver.find_element(By.XPATH,'/html/body/div[1]/div/main/div[2]/div/div[1]/div[2]').text
# sleep(2)
# results=results_1+results_2+results_3
# results_numbers = re.findall("(\d{8})", results)
# unspsc_column.append(results_numbers)

# %%
driver.quit()
