# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome import options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd
from time import sleep
import re
import random

# %%
df = pd.read_csv('Copy of Stanley BD.csv')
df = df.drop(0)
df = df.drop(1)
df.columns = df.iloc[0]
df = df.drop(2)

# %%
non_null_cat_num = df[~df['Catalog Number'].isnull()]
list_of_cat_numbers = non_null_cat_num['Catalog Number'].to_list()

# %%
image_column = {}

# %%
o = options.Options()
o.add_argument("start-maximized")
o.add_argument("--incognito")
driver = webdriver.Chrome(ChromeDriverManager().install(),options=o)

driver.get('https://bynder.sbdinc.com/login/')

username = driver.find_element(By.ID,"inputEmail")
password = driver.find_element(By.ID,"inputPassword")

username.send_keys("mlaufer@ceisales.com")
password.send_keys("caprice2902$")

driver.find_element(By.XPATH,'//*[@id="regular-login"]/div[4]/button').click()
driver.find_element(By.XPATH,'//*[@id="bynder"]/body/div[8]/div[1]/div[3]/div[1]/a/div[1]').click()
# for x in test:
#     print(f'item {y}')
#     search = driver.find_element(By.XPATH,'/html/body/header/div[1]/div[1]/form/input[4]')
#     search.send_keys(x)
#     sleep(2)
#     search.send_keys(Keys.ENTER)
#     sleep(2)
#     check = driver.find_element(By.XPATH,'//*[@id="rootAssetOverview"]/div').text
#     if check == no_results_text:
#         image_column.append('no result')
#     else:
#         sleep(2)
#         returned_container=driver.find_element(By.ID,'results-thumbs')
#         items = returned_container.find_elements(By.XPATH,'//*[@id="results-thumbs"]/div[contains(@class, "media-holder")]')
#         print(len(items))
#         one = items[0]
#         sleep(2.5)
#         one.click()
#         sleep(2)
#         for z in range(len(items)-1):
#             sleep(2)
#             next_ = driver.find_elements(By.XPATH,'//*[@id="image_enlarger"]/a[2]/span')
#             if len(next_)>0:
#                 image = driver.find_elements(By.XPATH,'//*[@id="previewImage"]/img[2]')
#                 if image[0].get_property('src')[-4:] == 'jpg':
#                     images.append(image[0])
#                 next_[0].click()
#             else:
#                 sleep(2)
#                 close = driver.find_elements(By.XPATH,'//*[@id="image_enlarger"]/div/a[1]/span')
#                 close[0].click()
#         close = driver.find_elements(By.XPATH,'//*[@id="image_enlarger"]/div/a[1]/span')
#         close[0].click()
#     image_column.append((x,images))
#     search=driver.find_element(By.XPATH,'/html/body/header/div[1]/div[1]/form/input[4]')
#     search.clear()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Driver [/Users/kelvinarellano/.wdm/drivers/chromedriver/mac64/98.0.4758.80/chromedriver] found in cache

# %%
# search = driver.find_element(By.XPATH,'/html/body/header/div[1]/div[1]/form/input[4]')
# search.send_keys(list_of_cat_numbers[2021])
# sleep(2)
# search.click()
# search.send_keys(Keys.ENTER)

# %%
#this to check
results = driver.find_element(By.XPATH,'//*[@id="rootAssetOverview"]/div')
results.text
# Out:
# '1866033_1\nTIF\nRegionNA\nBrandIRWIN\nContent TypePhotography\nContent FormatBeauty\n1866033_P1\nTIF\nRegionNA\nBrandIRWIN\nContent TypePhotography\nContent FormatPackaging'

# %%
no_result_text
# Out:
# 'There are currently no results\n<p>Please change your <strong>filters</strong>,<strong>tags</strong> or try a different <strong>search</strong></p>Enter new search\nNeed support?\n\nYou can send in a support request via email at DAM@sbdinc.com or contact the portal owner'

# %%
returned_container=driver.find_element(By.ID,'results-thumbs')
items = returned_container.find_elements(By.XPATH,'//*[@id="results-thumbs"]/div[contains(@class, "media-holder")]')
print(len(items))
one = items[0]
one.click()
# Out:
# 2

# %%
image = driver.find_elements(By.XPATH,'//*[@id="previewImage"]/img[2]')
image[0].get_property('src')
# Out:
# 'https://d3cy9zhslanhfa.cloudfront.net/media/0C77DB30-618A-4E06-BFED12BCDFF4EBC8/B62E641A-58C3-4B8F-8382D664FB61BF33/webimage-BEB32734-E76C-4994-9C330EF2E53018A5.jpg'

# %%
#waiting for elements to load code

# driver = webdriver.Firefox()
# driver.get("http://somedomain/url_that_delays_loading")
# try:
#     element = WebDriverWait(driver, 10).until(
#         EC.presence_of_element_located((By.ID, "myDynamicElement"))
#     )
# finally:
#     driver.quit()

# %%
search = driver.find_element(By.XPATH,'/html/body/header/div[1]/div[1]/form/input[4]')
search.send_keys(list_of_cat_numbers[2021])
sleep(2)
search.click()
search.send_keys(Keys.ENTER)
sleep(2)
images=[]
returned_container = driver.find_element(By.ID,'results-thumbs')
items = driver.find_elements(By.XPATH,'//*[@id="results-thumbs"]/div[contains(@class,"media-holder")]')
try:
#     items = WebDriverWait(driver,4).until(
#         EC.presence_of_all_elements_located(By.XPATH,'//*[@id="results-thumbs"]/div[contains(@class, "media-holder")]')
#     )
    one = items[0]
    sleep(1.5)
    one.click()
    for z in range(len(items)-1):
        try:
            next_ = WebDriverWait(driver,2).until(
                EC.presence_of_element_located(By.XPATH,'//*[@id="image_enlarger"]/a[2]/span')
            )
            image = driver.find_elements(By.XPATH,'//*[@id="previewImage"]/img[2]')
            if image[0].get_property('src')[-4:] == '.jpg':
                images.append(image[0])
            next_.click()
        except Exception:
            sleep(2)
            close = driver.find_elements(By.XPATH,'//*[@id="image_enlarger"]/div/a[1]/span')
            close[0].click()
except Exception:
    print('No Items')
finally:
    search=driver.find_element(By.XPATH,'/html/body/header/div[1]/div[1]/form/input[4]')
    search.clear()
