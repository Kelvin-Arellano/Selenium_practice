# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome import options
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd
from time import sleep
import re
import random
from random import randint

# %%
df = pd.read_csv('Copy of Stanley BD.csv')
df = df.drop(0)
df = df.drop(1)
df.columns = df.iloc[0]
df = df.drop(2)

# %%
non_null_cat_num = df[~df['Catalog Number'].isnull()]
list_of_cat_numbers = non_null_cat_num['Catalog Number'].to_list()

# %%
image_dict

# %%
o = options.Options()
o.add_argument("start-maximized")
o.add_argument("--incognito")
driver = webdriver.Chrome(ChromeDriverManager().install(),options=o)

driver.get('https://bynder.sbdinc.com/login/')

username = driver.find_element(By.ID,"inputEmail")
password = driver.find_element(By.ID,"inputPassword")

username.send_keys("mlaufer@ceisales.com")
password.send_keys("caprice2902$")

driver.find_element(By.XPATH,'//*[@id="regular-login"]/div[4]/button').click()
driver.find_element(By.XPATH,'//*[@id="bynder"]/body/div[8]/div[1]/div[3]/div[1]/a/div[1]').click()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 98.0.4758
# Get LATEST chromedriver version for 98.0.4758 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/98.0.4758.102/chromedriver_mac64.zip
# Driver has been saved in cache [/Users/kelvinarellano/.wdm/drivers/chromedriver/mac64/98.0.4758.102]

# %%
# for number in list_of_cat_numbers[4033:]:
#     driver.refresh()
#     search = driver.find_element(By.XPATH,'/html/body/header/div[1]/div[1]/form/input[4]')
#     images_list = []
#     search.send_keys(number)
#     sleep(randint(1,2))
#     search.send_keys(Keys.ENTER)
#     sleep(randint(2,3))
#     try:
#         images = driver.find_elements_by_tag_name('img')
#         for image in images:
#             images = driver.find_elements_by_tag_name('img')
#             images_list.append(image.get_attribute('src'))
#         image_dict[number] = images_list
#         print(number)
#     except StaleElementReferenceException as error:
#         print(error)
#     search = driver.find_element(By.XPATH,'/html/body/header/div[1]/div[1]/form/input[4]')
#     search.clear()
#     sleep(randint(2,3))

# %%
len(image_dict.keys())
# Out:
# 9683

# %%
driver.quit()

# %%
import pickle

# %%
image_file = open('images.txt', 'wb')
pickle.dump(image_dict, image_file)
image_file.close()

# %%
# athletes_file = open("athletes.txt", "rb")
# athletes = pickle.load(athletes_file)
# athletes_file.close()
# print(athletes)
